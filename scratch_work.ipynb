# %%
import pandas as pd 

df = pd.read_csv('data/raw/fight-songs-updated.csv')

# %%
df_big = df[df["conference"] == "Big Ten"]
df_big
# Out:
#             school conference               song_name  \
# 24        Illinois    Big Ten           Oskee-Wow-Wow
# 25         Indiana    Big Ten    Indiana, Our Indiana
# 26            Iowa    Big Ten         Iowa Fight Song
# 27        Maryland    Big Ten     Maryland Fight Song
# 28        Michigan    Big Ten             The Victors
# 29  Michigan State    Big Ten         Victory for MSU
# 30       Minnesota    Big Ten    The Minnesota Rouser
# 31        Nebraska    Big Ten    Dear Old Nebraska U.
# 32    Northwestern    Big Ten      Go! U Northwestern
# 33      Ohio State    Big Ten      Buckeye Battle Cry
# 34      Penn State    Big Ten         Fight On, State
# 35          Purdue    Big Ten             Hail Purdue
# 36         Rutgers    Big Ten     The Bells Must Ring
# 37       Wisconsin    Big Ten           On, Wisconsin
# 38          Oregon    Big Ten           Mighty Oregon
# 39            UCLA    Big Ten        Sons of Westwood
# 40             USC    Big Ten           Fight On, USC
# 41      Washington    Big Ten  Bow Down to Washington
#
#                                               writers  year student_writer  \
# 24                           H.R. Green and H.V. Hill  1910            Yes
# 25                 Russell P. Harker and Karl L. King  1912            Yes
# 26                                   Meredith Willson  1950             No
# 27                                        Ralph Davis  1939            Yes
# 28                                        Louis Elbel  1898            Yes
# 29         Francis Irving Lankey and Arthur L. Sayles  1915            Yes
# 30                                      Floyd Hutsell  1909             No
# 31                                        Harry Pecha  1924            Yes
# 32                              Theodore C. Van Etten  1912            Yes
# 33                                       Frank Crumit  1919             No
# 34                                     Joseph Sanders  1933             No
# 35             James R. Morrison and Edward S. Wotawa  1912            Yes
# 36                    Richard Hadden and W.E. Sanford  1931            Yes
# 37                        William Purdy and Carl Beck  1909             No
# 38             DeWitt Gilbert and Albert John Perfect  1916            Yes
# 39   Harold P. Williams and N. Loyall McLaren; Kel...  1959             No
# 40                                         Milo Sweet  1922            Yes
# 41                                   Lester J. Wilson  1915             No
#
#    official_song contest  bpm  sec_duration  ... win_won  victory_win_won  \
# 24           Yes      No  162            60  ...      No              Yes
# 25           Yes      No  150            63  ...      No               No
# 26           Yes      No  150            72  ...     Yes              Yes
# 27           Yes      No  142            56  ...     Yes              Yes
# 28           Yes      No   83           122  ...      No               No
# 29           Yes      No  145           112  ...     Yes              Yes
# 30           Yes     Yes  151            60  ...      No               No
# 31            No      No  136            94  ...      No               No
# 32           Yes      No  140            57  ...     Yes              Yes
# 33           Yes     Yes  178            89  ...     Yes              Yes
# 34           Yes      No  145            81  ...     Yes              Yes
# 35           Yes      No  160            86  ...      No              Yes
# 36           Yes     Yes   75            74  ...     Yes              Yes
# 37           Yes      No  132           134  ...     Yes              Yes
# 38           Yes      No   65            80  ...     Yes              Yes
# 39           Yes      No   72            69  ...      No               No
# 40           Yes     Yes   75            60  ...     Yes              Yes
# 41           Yes     Yes  139            89  ...      No              Yes
#
#     rah nonsense colors  men opponents spelling trope_count  \
# 24  Yes      Yes    Yes  Yes       Yes       No           6
# 25   No       No    Yes   No        No      Yes           3
# 26  Yes       No     No   No        No       No           3
# 27   No       No     No   No        No       No           3
# 28   No       No     No   No        No       No           0
# 29  Yes       No    Yes   No        No      Yes           5
# 30  Yes      Yes     No   No        No      Yes           3
# 31   No       No     No  Yes        No       No           1
# 32  Yes       No     No   No        No       No           4
# 33   No       No    Yes  Yes        No       No           5
# 34   No       No    Yes   No        No      Yes           5
# 35   No       No    Yes   No        No       No           2
# 36  Yes      Yes    Yes  Yes        No      Yes           8
# 37   No       No     No  Yes        No       No           3
# 38   No       No     No  Yes       Yes       No           5
# 39   No       No    Yes  Yes       Yes      Yes           5
# 40   No       No     No  Yes        No      Yes           5
# 41  Yes       No    Yes   No        No       No           4
#
#                 spotify_id
# 24  6C0vaoMxzM21yYgJBmGx5K
# 25  2Wbo5zdRDnq4pOgWL9avaG
# 26  604ELPPFgbFlW0SHoEYVJw
# 27  6PKoPWKJLOBI2K33RkFvbc
# 28  6wVbHLCBOCqp6052WcWXLG
# 29  4BSrPApxbeUNPA5Q8LyfMd
# 30  2EeyLSmHKdZulOKGcTpLS0
# 31  7z2TihIyf3IZR1r0AmI1Ik
# 32  4iWO9U49SZ0vvzto7qxRxN
# 33  2faIedehtxwQqYxRRc6T2L
# 34  5InlNNfIFQAvCL78VFgR5O
# 35  1bYZgec19T5gQJAUeIzq9W
# 36  7EdGMXzZjJKNHJaszbWTHi
# 37  4DmMOLdp4ZYvrAqemDBBbJ
# 38  4zPgdoDF3Od2dwQdPlGJtt
# 39  0XxQcPAThn9dOZ6NVFUfGl
# 40  23EM48kuqZWVltXE9bApcK
# 41  0OLQPcJ1jMwrXJbt81hHrx
#
# [18 rows x 23 columns]

# %%
round(df_big['bpm'].mean(), 2)
# Out:
# np.float64(127.78)

# %%
df_big['spelling'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 24     No
# 25    Yes
# 26     No
# 27     No
# 28     No
# 29    Yes
# 30    Yes
# 31     No
# 32     No
# 33     No
# 34    Yes
# 35     No
# 36    Yes
# 37     No
# 38     No
# 39    Yes
# 40    Yes
# 41     No
# Name: spelling, dtype: object>

# %%
df_big['spelling'] = df_big['spelling'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['opponents'] = df_big['opponents'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['men'] = df_big['men'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['colors'] = df_big['colors'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['nonsense'] = df_big['nonsense'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['rah'] = df_big['rah'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['win_won'] = df_big['win_won'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['victory'] = df_big['victory'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['fight'] = df_big['fight'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['victory_win_won'] = df_big['victory_win_won'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['contest'] = df_big['contest'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['official_song'] = df_big['official_song'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['student_writer'] = df_big['student_writer'].map({'Yes': 1, 'No': 0}).astype(int)
df_big['year'] = df_big['year'].astype(int)
# Out:
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['spelling'] = df_big['spelling'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['opponents'] = df_big['opponents'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['men'] = df_big['men'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['colors'] = df_big['colors'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['nonsense'] = df_big['nonsense'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['rah'] = df_big['rah'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['win_won'] = df_big['win_won'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['victory'] = df_big['victory'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['fight'] = df_big['fight'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['victory_win_won'] = df_big['victory_win_won'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['contest'] = df_big['contest'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['official_song'] = df_big['official_song'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['student_writer'] = df_big['student_writer'].map({'Yes': 1, 'No': 0}).astype(int)
# C:\Users\12248\AppData\Local\Temp\ipykernel_14908\444879105.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_big['year'] = df_big['year'].astype(int)

# %%
df_big["school"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 24          Illinois
# 25           Indiana
# 26              Iowa
# 27          Maryland
# 28          Michigan
# 29    Michigan State
# 30         Minnesota
# 31          Nebraska
# 32      Northwestern
# 33        Ohio State
# 34        Penn State
# 35            Purdue
# 36           Rutgers
# 37         Wisconsin
# 38            Oregon
# 39              UCLA
# 40               USC
# 41        Washington
# Name: school, dtype: object>

# %%
df_big
# Out:
#             school conference               song_name  \
# 24        Illinois    Big Ten           Oskee-Wow-Wow
# 25         Indiana    Big Ten    Indiana, Our Indiana
# 26            Iowa    Big Ten         Iowa Fight Song
# 27        Maryland    Big Ten     Maryland Fight Song
# 28        Michigan    Big Ten             The Victors
# 29  Michigan State    Big Ten         Victory for MSU
# 30       Minnesota    Big Ten    The Minnesota Rouser
# 31        Nebraska    Big Ten    Dear Old Nebraska U.
# 32    Northwestern    Big Ten      Go! U Northwestern
# 33      Ohio State    Big Ten      Buckeye Battle Cry
# 34      Penn State    Big Ten         Fight On, State
# 35          Purdue    Big Ten             Hail Purdue
# 36         Rutgers    Big Ten     The Bells Must Ring
# 37       Wisconsin    Big Ten           On, Wisconsin
# 38          Oregon    Big Ten           Mighty Oregon
# 39            UCLA    Big Ten        Sons of Westwood
# 40             USC    Big Ten           Fight On, USC
# 41      Washington    Big Ten  Bow Down to Washington
#
#                                               writers  year  student_writer  \
# 24                           H.R. Green and H.V. Hill  1910               1
# 25                 Russell P. Harker and Karl L. King  1912               1
# 26                                   Meredith Willson  1950               0
# 27                                        Ralph Davis  1939               1
# 28                                        Louis Elbel  1898               1
# 29         Francis Irving Lankey and Arthur L. Sayles  1915               1
# 30                                      Floyd Hutsell  1909               0
# 31                                        Harry Pecha  1924               1
# 32                              Theodore C. Van Etten  1912               1
# 33                                       Frank Crumit  1919               0
# 34                                     Joseph Sanders  1933               0
# 35             James R. Morrison and Edward S. Wotawa  1912               1
# 36                    Richard Hadden and W.E. Sanford  1931               1
# 37                        William Purdy and Carl Beck  1909               0
# 38             DeWitt Gilbert and Albert John Perfect  1916               1
# 39   Harold P. Williams and N. Loyall McLaren; Kel...  1959               0
# 40                                         Milo Sweet  1922               1
# 41                                   Lester J. Wilson  1915               0
#
#     official_song  contest  bpm  sec_duration  ...  win_won  victory_win_won  \
# 24              1        0  162            60  ...        0                1
# 25              1        0  150            63  ...        0                0
# 26              1        0  150            72  ...        1                1
# 27              1        0  142            56  ...        1                1
# 28              1        0   83           122  ...        0                0
# 29              1        0  145           112  ...        1                1
# 30              1        1  151            60  ...        0                0
# 31              0        0  136            94  ...        0                0
# 32              1        0  140            57  ...        1                1
# 33              1        1  178            89  ...        1                1
# 34              1        0  145            81  ...        1                1
# 35              1        0  160            86  ...        0                1
# 36              1        1   75            74  ...        1                1
# 37              1        0  132           134  ...        1                1
# 38              1        0   65            80  ...        1                1
# 39              1        0   72            69  ...        0                0
# 40              1        1   75            60  ...        1                1
# 41              1        1  139            89  ...        0                1
#
#     rah  nonsense  colors  men  opponents  spelling  trope_count  \
# 24    1         1       1    1          1         0            6
# 25    0         0       1    0          0         1            3
# 26    1         0       0    0          0         0            3
# 27    0         0       0    0          0         0            3
# 28    0         0       0    0          0         0            0
# 29    1         0       1    0          0         1            5
# 30    1         1       0    0          0         1            3
# 31    0         0       0    1          0         0            1
# 32    1         0       0    0          0         0            4
# 33    0         0       1    1          0         0            5
# 34    0         0       1    0          0         1            5
# 35    0         0       1    0          0         0            2
# 36    1         1       1    1          0         1            8
# 37    0         0       0    1          0         0            3
# 38    0         0       0    1          1         0            5
# 39    0         0       1    1          1         1            5
# 40    0         0       0    1          0         1            5
# 41    1         0       1    0          0         0            4
#
#                 spotify_id
# 24  6C0vaoMxzM21yYgJBmGx5K
# 25  2Wbo5zdRDnq4pOgWL9avaG
# 26  604ELPPFgbFlW0SHoEYVJw
# 27  6PKoPWKJLOBI2K33RkFvbc
# 28  6wVbHLCBOCqp6052WcWXLG
# 29  4BSrPApxbeUNPA5Q8LyfMd
# 30  2EeyLSmHKdZulOKGcTpLS0
# 31  7z2TihIyf3IZR1r0AmI1Ik
# 32  4iWO9U49SZ0vvzto7qxRxN
# 33  2faIedehtxwQqYxRRc6T2L
# 34  5InlNNfIFQAvCL78VFgR5O
# 35  1bYZgec19T5gQJAUeIzq9W
# 36  7EdGMXzZjJKNHJaszbWTHi
# 37  4DmMOLdp4ZYvrAqemDBBbJ
# 38  4zPgdoDF3Od2dwQdPlGJtt
# 39  0XxQcPAThn9dOZ6NVFUfGl
# 40  23EM48kuqZWVltXE9bApcK
# 41  0OLQPcJ1jMwrXJbt81hHrx
#
# [18 rows x 23 columns]

# %%
df_big.columns
# Out:
# Index(['school', 'conference', 'song_name', 'writers', 'year',
#        'student_writer', 'official_song', 'contest', 'bpm', 'sec_duration',
#        'fight', 'number_fights', 'victory', 'win_won', 'victory_win_won',
#        'rah', 'nonsense', 'colors', 'men', 'opponents', 'spelling',
#        'trope_count', 'spotify_id'],
#       dtype='object')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
